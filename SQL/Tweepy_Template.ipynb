# %%
import numpy as np
import pandas as pd
import tweepy
import json

# %%
consumer_token = 'your consumer_token'
consumer_secret = 'your consumer_secret' 
access_token = 'your access_token'                  
access_token_secret = 'your token_secret'               
auth = tweepy.OAuthHandler(consumer_token, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Publix Freebies – 16 Different Products or 35 Items! https://t.co/pYMdBNhYrW This week there are sooo many great de… https://t.co/HLRWbMpW45
# Trump throwing paper towel rolls to desperate, hurricane-ravaged Puerto Ricans is one of my favorite “became presid… https://t.co/zb8GQ1UEAw
# MacRumors Giveaway: Win a USB-C Pro Hub With Ethernet From Satechi https://t.co/R48gOmiomL by @julipuli https://t.co/LR0ZEudoYp
# RT @VideoInkNews: Kevin Durant’s Thirty Five Media Partners with American Family on ‘Dream to Achieve’ a New Branded Content Series
# @thirty…
# RT @amfam: @KDTrey5 shares how he got involved in tech in the first episode of Dream to Achieve. Watch the full episode with health tech st…
# Deals: Last Call for Exclusive Twelve South Sale, HomePod for $300, and Beats Studio3 for $200… https://t.co/LguxZ0G9rE
# Kick ass Flan!!! https://t.co/m9hgmLez09
# ...

# %%
api.update_profile(location = 'Fuqua, of course!')
# Out:
# User(_api=<tweepy.api.API object at 0x7fa5568dcb00>, _json={'id': 154585341, 'id_str': '154585341', 'name': 'Ryan Burk', 'screen_name': 'ryanburk9', 'location': 'Fuqua, of course!', 'profile_location': None, 'description': 'Mediocre Golfer', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 12, 'friends_count': 44, 'listed_count': 1, 'created_at': 'Fri Jun 11 17:05:09 +0000 2010', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': 'en', 'status': {'created_at': 'Tue Jan 27 15:13:40 +0000 2015', 'id': 560093286694940673, 'id_str': '560093286694940673', 'text': 'SNOWMAGEDDON 2015 #6TO10 #STRONGERTHANTHESTORM  #INACCUWEATHER @CecilyTynan @6abcadamjoseph @davidmurphy6abc http://t.co/oIj7cI8zcp', 'truncated': False, 'entities': {'hashtags': [{'text': '6TO10', 'indices': [18, 24]}, {'text': 'STRONGERTHANTHESTORM', 'indices': [25, 46]}, {'text': 'INACCUWEATHER', 'indi
# ...

# %%
api.update_status("Isn't this data infrastructure stuff great!")
# Out:
# Status(_api=<tweepy.api.API object at 0x7fa5568dcb00>, _json={'created_at': 'Fri Aug 24 18:24:45 +0000 2018', 'id': 1033057541427740672, 'id_str': '1033057541427740672', 'text': "Isn't this data infrastructure stuff great!", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://placeholder.com/" rel="nofollow">TweepyExample82017</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 154585341, 'id_str': '154585341', 'name': 'Ryan Burk', 'screen_name': 'ryanburk9', 'location': 'Fuqua, of course!', 'description': 'Mediocre Golfer', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 12, 'friends_count': 44, 'listed_count': 1, 'created_at': 'Fri Jun 11 17:05:09 +0000 2010', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': 
# ...

# %%
temp=api.user_timeline(id='realDonaldTrump')

# %%
temp
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fa5568dcb00>, _json={'created_at': 'Fri Aug 24 17:36:02 +0000 2018', 'id': 1033045280143355904, 'id_str': '1033045280143355904', 'text': '...Secretary Pompeo looks forward to going to North Korea in the near future, most likely after our Trading relatio… https://t.co/MdhLZ8Vhzi', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/MdhLZ8Vhzi', 'expanded_url': 'https://twitter.com/i/web/status/1033045280143355904', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1033045274866999297, 'in_reply_to_status_id_str': '1033045274866999297', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 25073877, 'id_str': '25073877', 'name': 'Donald J. Trump', 'screen_name': 'r
# ...

# %%
idlist=[]
createdatlist=[]
textlist=[]
for tweets in tweepy.Cursor(api.user_timeline, id='realDonaldTrump').items(200):
    idlist.append(tweets.id)
    createdatlist.append(tweets.created_at)
    textlist.append(tweets.text)
tweetdata = {
    "id":idlist,
    "createdat":createdatlist,
    "text":textlist
}

# %%
tweetdf=pd.DataFrame(tweetdata)

# %%
tweetdf.head()
# Out:
#             createdat                   id  \
# 0 2018-08-24 17:36:02  1033045280143355904
# 1 2018-08-24 17:36:01  1033045274866999297
# 2 2018-08-24 17:36:00  1033045273361178624
# 3 2018-08-24 16:10:25  1033023735517863936
# 4 2018-08-24 11:34:13  1032954224529817600
#
#                                                 text
# 0  ...Secretary Pompeo looks forward to going to ...
# 1  ...Additionally, because of our much tougher T...
# 2  I have asked Secretary of State Mike Pompeo no...
# 3                            https://t.co/0a25gApyJ6
# 4  Social Media Giants are silencing millions of ...

# %%
tweetdf.text=tweetdf.text.astype(str)

# %%
tweetdf[tweetdf.text.str.contains('love',case=False,na=False)]
# Out:
#               createdat                   id  \
# 15  2018-08-22 00:45:19  1032066147598958592
# 141 2018-08-11 18:59:17  1028355187939987465
# 164 2018-08-08 15:25:55  1027214330503352320
# 186 2018-08-05 21:52:57  1026224564420968450
# 195 2018-08-05 01:43:00  1025920073159110657
# 196 2018-08-05 00:28:25  1025901304047198209
#
#                                                   text
# 15   Thank you West Virginia. I love you! https://t...
# 141  Hundreds of Bikers for Trump just joined me at...
# 164  As long as I campaign and/or support Senate an...
# 186  RT @realDonaldTrump: A great night in Ohio’s 1...
# 195  A great night in Ohio’s 12th Congressional Dis...
# 196  Thank you Ohio. I love you! https://t.co/HYSaQ...

# %%
tweetdf[tweetdf.text.str.contains('hate',case=False,na=False)]
# Out:
#               createdat                   id  \
# 193 2018-08-05 11:38:12  1026069857589227520
#
#                                                   text
# 193  The Fake News hates me saying that they are th...

# %%
tweetdf[tweetdf.text.str.contains('fake',case=False,na=False)]
# Out:
#               createdat                   id  \
# 4   2018-08-24 11:34:13  1032954224529817600
# 43  2018-08-21 11:10:49  1031861173149413376
# 60  2018-08-19 12:14:44  1031152483949838336
# 64  2018-08-19 11:01:47  1031134125602820096
# 74  2018-08-18 11:32:17  1030779412973846529
# 104 2018-08-16 12:50:44  1030074380397752320
# 159 2018-08-12 12:24:12  1028618150944944129
# 163 2018-08-11 18:28:48  1028347518822825984
# 185 2018-08-08 15:14:26  1027211440225243137
#
#                                                   text
# 4    Social Media Giants are silencing millions of ...
# 43   Fake News, of which there is soooo much (this ...
# 60   Some members of the media are very Angry at th...
# 64   The failing @nytimes wrote a Fake piece today ...
# 74   .....Censorship is a very dangerous thing &amp...
# 104  THE FAKE NEWS MEDIA IS THE OPPOSITION PARTY. I...
# 159  .@JudgeJeanine  “Bob Mueller, isn’t your whole...
# 163  The big story that the Fake News Media refuses...
# ...
